# %%
import requests

url = "http://www.wamis.go.kr:8080/wamis/openapi/wkw/wl_dubwlobs"

querystring = {"servicekey":"f3e1f3409bed2e5d314e804e6380f3464ad7531ae4"}

payload = "------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"files\"\r\n\r\ndump.sql\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW--"
headers = {
    'content-type': "multipart/form-data; boundary=----WebKitFormBoundary7MA4YWxkTrZu0gW",
    'cache-control': "no-cache",
    'postman-token': "ca14d884-7289-1123-793d-321091db72ce"
    }

response = requests.request("GET", url, data=payload, headers=headers, params=querystring)

print(response.text)
# Out:
# {"result":{"code":"success","msg":"완료되었습니다!"},"count":950,"list":[{"bbsnnm":"한강","obscd":"1001602","obsnm":"평창군(송정교)","clsyn":"운영","obsknd":"T/M","sbsncd":"100108","mngorg":"환경부"},{"bbsnnm":"한강","obscd":"1001603","obsnm":"태백시(무사교)","clsyn":"운영","obsknd":"T/M","sbsncd":"100101","mngorg":"한국수자원공사"},{"bbsnnm":"한강","obscd":"1001605","obsnm":"송천1교","clsyn":"운영","obsknd":"T/M","sbsncd":"100105","mngorg":"한국수력원자력"},{"bbsnnm":"한강","obscd":"1001607","obsnm":"삼척시(번천교)","clsyn":"운영","obsknd":"T/M","sbsncd":"100101","mngorg":"한국수자원공사"},{"bbsnnm":"한강","obscd":"1001610","obsnm":"삼척시(광동댐)","clsyn":"폐쇄","obsknd":"T/M","sbsncd":"100102","mngorg":"한국수자원공사"},{"bbsnnm":"한강","obscd":"1001613","obsnm":"삼척시(광동교)","clsyn":"운영","obsknd":"T/M","sbsncd":"100102","mngorg":"한국수자원공사"},{"bbsnnm":"한강","obscd":"1001615","obsnm":"삼척시(갈밭교)","clsyn":"운영","obsknd":"T/M","sbsncd":"100102","mngorg":"한국수자원공사"},{"bbsnnm":"한강","obscd":"1001620","obsnm":"정선군(송계교)","clsyn":"운영","obsknd":"T/M","sbsncd":"100103","mngorg":"환경부"},
# ...

# %%
from pprint import pprint

import requests
import pandas as pd
import json
import sys

url = "http://www.wamis.go.kr:8080/wamis/openapi/wkw/wl_dubwlobs"
querystring = {"servicekey":"f3e1f3409bed2e5d314e804e6380f3464ad7531ae4", "oper" : "y"}
payload = "------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"files\"\r\n\r\ndump.sql\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW--"

headers = {
    'content-type': "multipart/form-data; boundary=----WebKitFormBoundary7MA4YWxkTrZu0gW",
    'cache-control': "no-cache",
    'postman-token': "ca14d884-7289-1123-793d-321091db72ce"
    }

response = requests.request("GET", url, data=payload, headers=headers, params=querystring)
#print(response.text)

dat = json.loads(response.text)
dat = {"result":dat,"list":dat['list']}
df = pd.DataFrame.from_dict(dat['list'])

df.to_excel('wapost.xlsx')



# dat = []

# dat.extend(response.json()["result"])

# df = pd.DataFrame(dat)

# #df["bbsnnm"] = df["bbsnnm"].astype(str)
# df["obscd"] = df["obscd"].astype(str)
# df["obsnm"] = df["obsnm"].astype(str) 
# df["clsyn"] = df["clsyn"].astype(str)
# df["obsknd"] = df["obsknd"].astype(str)
# df["sbsncd"] = df["sbsncd"].astype(str)
# df["mngorg"] = df["mngorg"].astype(str)

# df.to_excel('wlpost.xlsx')

# %%
dat['list']
# Out:
# [{'bbsnnm': '한강',
#   'obscd': '1001602',
#   'obsnm': '평창군(송정교)',
#   'clsyn': '운영',
#   'obsknd': 'T/M',
#   'sbsncd': '100108',
#   'mngorg': '환경부'},
#  {'bbsnnm': '한강',
#   'obscd': '1001603',
#   'obsnm': '태백시(무사교)',
#   'clsyn': '운영',
#   'obsknd': 'T/M',
#   'sbsncd': '100101',
#   'mngorg': '한국수자원공사'},
#  {'bbsnnm': '한강',
#   'obscd': '1001605',
#   'obsnm': '송천1교',
#   'clsyn': '운영',
#   'obsknd': 'T/M',
#   'sbsncd': '100105',
#   'mngorg': '한국수력원자력'},
#  {'bbsnnm': '한강',
#   'obscd': '1001607',
#   'obsnm': '삼척시(번천교)',
#   'clsyn': '운영',
#   'obsknd': 'T/M',
#   'sbsncd': '100101',
#   'mngorg': '한국수자원공사'},
#  {'bbsnnm': '한강',
#   'obscd': '1001610',
#   'obsnm': '삼척시(광동댐)',
#   'clsyn': '폐쇄',
#   'obsknd': 'T/M',
#   'sbsncd': '100102',
#   'mngorg': '한국수자원공사'},
#  {'bbsnnm': '한강',
#   'obscd': '1001613',
#   'obsnm': '삼척시(광동교)',
#   'clsyn': '운영',
#   'obsknd': 'T/M',
#   'sbsncd': '100102',
#   'mngorg': '한국수자원공사'},
#  {'bbsnnm': '한강',
#   'obscd': '1001615',
# ...

# %%
import requests

url = "http://www.wamis.go.kr:8080/wamis/openapi/wkw/wl_hrdata"

querystring = {"servicekey":"f3e1f3409bed2e5d314e804e6380f3464ad7531ae4","obscd":"1001602","startdt":"20201026","enddt":"20201026"}

payload = "------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"files\"\r\n\r\ndump.sql\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW--"
headers = {
    'content-type': "multipart/form-data; boundary=----WebKitFormBoundary7MA4YWxkTrZu0gW",
    'cache-control': "no-cache",
    'postman-token': "a3be6974-a29d-32b3-0a74-5fcc1e4ff88b"
    }

response = requests.request("GET", url, data=payload, headers=headers, params=querystring)

print(response.text)

# %%
from pprint import pprint

import requests
import pandas as pd
import json
import sys

url = "http://www.wamis.go.kr:8080/wamis/openapi/wkw/flw_dubobsif"

querystring = {"servicekey":"f3e1f3409bed2e5d314e804e6380f3464ad7531ae4"}

payload = "------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"files\"\r\n\r\ndump.sql\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW--"
headers = {
    'content-type': "multipart/form-data; boundary=----WebKitFormBoundary7MA4YWxkTrZu0gW",
    'cache-control': "no-cache",
    'postman-token': "eb5db2df-9568-3af3-a594-06ad44af8c20"
    }

response = requests.request("GET", url, data=payload, headers=headers, params=querystring)
#print(response.text)

dat = json.loads(response.text)
dat = {"result":dat,"list":dat['list']}
df = pd.DataFrame.from_dict(dat['list'])

df.to_excel('wlpost.xlsx')



# dat = []

# dat.extend(response.json()["result"])

# df = pd.DataFrame(dat)

# #df["bbsnnm"] = df["bbsnnm"].astype(str)
# df["obscd"] = df["obscd"].astype(str)
# df["obsnm"] = df["obsnm"].astype(str) 
# df["clsyn"] = df["clsyn"].astype(str)
# df["obsknd"] = df["obsknd"].astype(str)
# df["sbsncd"] = df["sbsncd"].astype(str)
# df["mngorg"] = df["mngorg"].astype(str)

# df.to_excel('wlpost.xlsx')

# %%
import requests

url = "http://www.wamis.go.kr:8080/wamis/openapi/wkw/wl_hrdata"

querystring = {"servicekey":"f3e1f3409bed2e5d314e804e6380f3464ad7531ae4","obscd":"1001602","startdt":"20201010","enddt":"20201011"}

payload = "------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"files\"\r\n\r\ndump.sql\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW--"
headers = {
    'content-type': "multipart/form-data; boundary=----WebKitFormBoundary7MA4YWxkTrZu0gW",
    'cache-control': "no-cache",
    'postman-token': "ba56118f-af74-fc0b-708d-00ec09c20ed5"
    }

response = requests.request("GET", url, data=payload, headers=headers, params=querystring)

print(response.text)
# Out:
# {"result":{"code":"success","msg":"완료되었습니다!"},"count":48,"list":[{"ymdh":"2020101001","wl":"165"},{"ymdh":"2020101002","wl":"165"},{"ymdh":"2020101003","wl":"165"},{"ymdh":"2020101004","wl":"165"},{"ymdh":"2020101005","wl":"166"},{"ymdh":"2020101006","wl":"165"},{"ymdh":"2020101007","wl":"165"},{"ymdh":"2020101008","wl":"166"},{"ymdh":"2020101009","wl":"165"},{"ymdh":"2020101010","wl":"165"},{"ymdh":"2020101011","wl":"165"},{"ymdh":"2020101012","wl":"165"},{"ymdh":"2020101013","wl":"165"},{"ymdh":"2020101014","wl":"165"},{"ymdh":"2020101015","wl":"165"},{"ymdh":"2020101016","wl":"165"},{"ymdh":"2020101017","wl":"164"},{"ymdh":"2020101018","wl":"165"},{"ymdh":"2020101019","wl":"164"},{"ymdh":"2020101020","wl":"165"},{"ymdh":"2020101021","wl":"165"},{"ymdh":"2020101022","wl":"164"},{"ymdh":"2020101023","wl":"165"},{"ymdh":"2020101024","wl":"165"},{"ymdh":"2020101101","wl":"165"},{"ymdh":"2020101102","wl":"165"},{"ymdh":"2020101103","wl":"165"},{"ymdh":"2020101104","wl":"165"},{"ymdh":"
# ...

# %%
import requests
import pandas as pd
import datetime
import json
import sys

def convert_strtdat(data): #예외 처리
    try:
        if data[-2:] == '24':
            d = datetime.datetime.strptime(data[:-2], '%Y%m%d')
            d = d + datetime.timedelta(days=1)
        else:
            d = datetime.datetime.strptime(data, '%Y%m%d%H')
        return d
    except Exception as e:
        print(f"[!] {data} is Not Date type.")
        sys.exit(1)
        
url = "http://www.wamis.go.kr:8080/wamis/openapi/wkw/wl_hrdata"

headers = {
    'content-type': "multipart/form-data; boundary=----WebKitFormBoundary7MA4YWxkTrZu0gW",
    'cache-control': "no-cache",
    'postman-token': "ba56118f-af74-fc0b-708d-00ec09c20ed5"
}

#obscd_list = ["1001602", "1001603"]

#result_list = []
#for obscd in obscd_list:
querystring = {"servicekey":"f3e1f3409bed2e5d314e804e6380f3464ad7531ae4","obscd":"5301690","startdt":"20190901","enddt":"20200301"}
payload = "------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"files\"\r\n\r\ndump.sql\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW--"

#print(response.text)
response = requests.request("GET", url, data=payload, headers=headers, params=querystring)
# check function
dat = json.loads(response.text)

df = pd.DataFrame.from_dict(dat['list'])
#df.info()
#df["obscd"] = df["obscd"] 
df["ymdh"] = df['ymdh'].apply(convert_strtdat)
df["wl"] = df["wl"].astype(float)
df.info()

df4hours = df.set_index("ymdh").resample("4H").mean() #4시간 단위로 출력
df4hours.to_excel('test31.xlsx')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4368 entries, 0 to 4367
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ymdh    4368 non-null   datetime64[ns]
#  1   wl      4368 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 68.4 KB

# %%
import requests
import pandas as pd
import datetime
import json
import sys

def convert_strtdat(data): #예외 처리
    try:
        if data[-2:] == '24':
            d = datetime.datetime.strptime(data[:-2], '%Y%m%d')
            d = d + datetime.timedelta(days=1)
        else:
            d = datetime.datetime.strptime(data, '%Y%m%d%H')
        return d
    except Exception as e:
        print(f"[!] {data} is Not Date type.")
        sys.exit(1)
        
url = "http://www.wamis.go.kr:8080/wamis/openapi/wkw/wl_hrdata"

headers = {
    'content-type': "multipart/form-data; boundary=----WebKitFormBoundary7MA4YWxkTrZu0gW",
    'cache-control': "no-cache",
    'postman-token': "ba56118f-af74-fc0b-708d-00ec09c20ed5"
}

#obscd_list = ["1001602", "1001603"]

#result_list = []
#for obscd in obscd_list:
querystring = {"servicekey":"f3e1f3409bed2e5d314e804e6380f3464ad7531ae4","obscd":"5301690","startdt":"20200301","enddt":"20200901"}
payload = "------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"files\"\r\n\r\ndump.sql\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW--"

#print(response.text)
response = requests.request("GET", url, data=payload, headers=headers, params=querystring)
# check function
dat = json.loads(response.text)

df = pd.DataFrame.from_dict(dat['list'])
#df.info()
#df["obscd"] = df["obscd"] 
df["ymdh"] = df['ymdh'].apply(convert_strtdat)
df["wl"] = df["wl"].astype(float)
df.info()

df4hours = df.set_index("ymdh").resample("4H").mean() #4시간 단위로 출력
df4hours.to_excel('test32.xlsx')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4416 entries, 0 to 4415
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ymdh    4416 non-null   datetime64[ns]
#  1   wl      4416 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 69.1 KB

# %%
import requests

url = "http://www.wamis.go.kr:8080/wamis/openapi/wkw/flw_dtdata"

querystring = {"servicekey":"f3e1f3409bed2e5d314e804e6380f3464ad7531ae4","obscd":"1003660","yyyy":"2019"}

payload = "------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"files\"\r\n\r\ndump.sql\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW--"
headers = {
    'content-type': "multipart/form-data; boundary=----WebKitFormBoundary7MA4YWxkTrZu0gW",
    'cache-control': "no-cache",
    'postman-token': "76d670ad-b985-2759-cd72-1a7b53969492"
    }

response = requests.request("GET", url, data=payload, headers=headers, params=querystring)

print(response.text)

# %%
# 유량 구하는 코딩
import requests
import pandas as pd
import datetime
import json
import sys
        
url = "http://www.wamis.go.kr:8080/wamis/openapi/wkw/flw_dtdata"

headers = {
    'content-type': "multipart/form-data; boundary=----WebKitFormBoundary7MA4YWxkTrZu0gW",
    'cache-control': "no-cache",
    'postman-token': "76d670ad-b985-2759-cd72-1a7b53969492"
}

#obscd_list = ["1001602", "1001603"]

#result_list = []
#for obscd in obscd_list:
querystring = {"servicekey":"f3e1f3409bed2e5d314e804e6380f3464ad7531ae4","obscd":"5101631","yyyy":"2020"}
payload = "------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"files\"\r\n\r\ndump.sql\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW--"

#print(response.text)
response = requests.request("GET", url, data=payload, headers=headers, params=querystring)
# check function
dat = json.loads(response.text)

df = pd.DataFrame.from_dict(dat['list'])
#df.info()
#df["obscd"] = df["obscd"] 
df["ymd"] = df['ymd'].apply(str)
df["fw"] = df["fw"].astype(float)
df.info()

df.to_excel('test1.xlsx')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# c:\users\gb-ofc-006\appdata\local\programs\python\python38\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# c:\users\gb-ofc-006\appdata\local\programs\python\python38\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# c:\users\gb-ofc-006\appdata\local\programs\python\python38\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ...

# %%
dat
# Out:
# {'result': {'code': 'success', 'msg': '완료되었습니다!'},
#  'count': 302,
#  'list': [{'ymd': '20200101', 'fw': '.75'},
#   {'ymd': '20200102', 'fw': '.75'},
#   {'ymd': '20200103', 'fw': '.72'},
#   {'ymd': '20200104', 'fw': '.69'},
#   {'ymd': '20200105', 'fw': '.69'},
#   {'ymd': '20200106', 'fw': '.69'},
#   {'ymd': '20200107', 'fw': '3.63'},
#   {'ymd': '20200108', 'fw': '37.53'},
#   {'ymd': '20200109', 'fw': '15.84'},
#   {'ymd': '20200110', 'fw': '8.37'},
#   {'ymd': '20200111', 'fw': '6.39'},
#   {'ymd': '20200112', 'fw': '5.18'},
#   {'ymd': '20200113', 'fw': '4.31'},
#   {'ymd': '20200114', 'fw': '3.7'},
#   {'ymd': '20200115', 'fw': '3.28'},
#   {'ymd': '20200116', 'fw': '2.93'},
#   {'ymd': '20200117', 'fw': '2.61'},
#   {'ymd': '20200118', 'fw': '2.46'},
#   {'ymd': '20200119', 'fw': '2.28'},
#   {'ymd': '20200120', 'fw': '2.16'},
#   {'ymd': '20200121', 'fw': '1.96'},
#   {'ymd': '20200122', 'fw': '1.87'},
#   {'ymd': '20200123', 'fw': '1.77'},
# ...
